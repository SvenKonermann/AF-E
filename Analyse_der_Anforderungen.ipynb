# %% [markdown]
# # __Analyse der Anforderungen__
#
# In diesem Schritt werden die meistgenannten Anforderungen identifiziert und in ein Wörterbuch überführt

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords  
from gensim.models.phrases import Phrases, Phraser
pd.set_option('display.max_colwidth', 50)
import os

# Working-Directory
os.chdir('C:/Users/Sven Konermann/Documents/Master/2_Semester/aF_E_Faelle/Unterlagen/00_all')

# %%
# Einlesen der Daten über ein csv File
data = pd.read_csv("Inserate_clean_Gesamtdatenanalyse.csv", sep=";")
print(data.shape)

# Auf Null-Werte prüfen und diese löschen
data = data[~data['Text_Anforderungen'].isnull()]

# Erneutes Tokenisieren
data['text_tok'] = data.apply(lambda row: nltk.word_tokenize(row['Text_Anforderungen']), axis=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 # Einlesen der Daten über ein csv File
# ----> 2 data = pd.read_csv("Inserate_clean_Gesamtdatenanalyse.csv", sep=";")
#       3 print(data.shape)
#       5 # Auf Null-Werte prüfen und diese löschen
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Inserate_clean_Gesamtdatenanalyse.csv'

# %%
# Jahr auswählen, für das ein Wörterbuch erstellt werden soll
data = data.loc[data.year == 2021]

# %% [markdown]
# Phrasen sammeln

# %%
# Finden von oft vorkommenden Phrasen mit einer Länge zwischen 2 und 4 Wörtern
from nltk import ngrams
vals = [y for x in data['Text_Anforderungen'] for y in x.split()]

n = [2,3,4]
a = pd.Series([y for x in n for y in ngrams(vals, x)]).value_counts()
a.head(25)
# Out:
# (wort, schrift)                          70
# (41, 44)                                 65
# (vollständig, bewerbungsunterlagen)      61
# (intern, extern)                         60
# (gut, kenntnis)                          60
# (gut, deutsch)                           59
# (erfahrung, leitung)                     51
# (mehrjährig, erfahrung)                  50
# (per, email)                             49
# (ch8048, zürich, 41)                     48
# (zürich, 41, 44)                         48
# (maxhöggerstrasse, 2, ch8048)            48
# (maxhöggerstrasse, 2)                    48
# (zürich, 41)                             48
# (44, 576)                                48
# (maxhöggerstrasse, 2, ch8048, zürich)    48
# (2, ch8048, zürich, 41)                  48
# (ch8048, zürich, 41, 44)                 48
# (zürich, 41, 44, 576)                    48
# (2, ch8048, zürich)                      48
# (2, ch8048)                              48
# (ch8048, zürich)                         48
# (41, 44, 576)                            48
# (p, langdech)                            47
# (it, maxhöggerstrasse)                   46
# dtype: int64

# %%
# Abspeichern in ein CSV als Basis für das Wörterbuch
a.to_csv("ngram_count_all_Data.csv", encoding="utf-8", sep=";")

# %% [markdown]
# Fix-Wörter sammeln

# %%
# Einmal vorkommende Wörter in Set abspeichern
results = set()
data['text_tok'].apply(results.update)
n = results
len(n)
# Out:
# 14668

# %%
# Vergleiche das Vorkommen von unique words im Text_new (Unique words list kommt vom Tokanizing oben).
# Danach ausschreiben der Begriffe, welche Anforderungen entsprechen, in ein Wörterbuch
wordsets = [ frozenset(document.split(' ')) for document in data['Text_Anforderungen'] ]
results = []
for word in n:
    count = sum( 1 for s in wordsets if word in s )
    results.append((count, word))
for count, word in sorted(results, reverse=True):
    if count >= 25: # Mindestanzahl Nennungen der Begriffe
        print(word, ";", count)
# Out:
# sowie ; 352
# gut ; 335
# erfahrung ; 322
# projekt ; 308
# bereich ; 262
# it ; 240
# deutsch ; 234
# freuen ; 231
# kunde ; 228
# neu ; 215
# team ; 209
# suchen ; 207
# kenntnis ; 203
# hoch ; 199
# informatik ; 194
# aufgabe ; 182
# bieten ; 173
# technisch ; 167
# weit ; 161
# extern ; 160
# teamfähig ; 159
# 41 ; 157
# umfeld ; 156
# gerne ; 156
# business ; 156
# persönlichkeit ; 148
# intern ; 147
# ausbildung ; 147
# unternehmen ; 143
# erfolgreich ; 143
# umsetzung ; 142
# leitung ; 139
# bewerbungsunterlagen ; 139
# spannend ; 138
# jahr ; 138
# wirtschaftsinformatik ; 132
# projektleitungserfahrung ; 129
# modern ; 128
# schweiz ; 127
# projektleiter ; 125
# bringen ; 124
# per ; 123
# lösung ; 122
# weiterbildung ; 121
# agil ; 121
# verfügen ; 119
# arbeiten ; 118
# attraktiv ; 115
# ag ; 115
# profil ; 112
# wort ; 111
# management ; 111
# komplex ; 111
# vorteil ; 109
# verschieden ; 107
# zürich ; 105
# analytisch ; 105
# interesse ; 104
# innovativ ; 104
# tätigkeit ; 103
# führen ; 102
# fähigkeit ; 101
# berufserfahrung ; 101
# englischkenntnisse ; 100
# einführung ; 100
# abgeschlossen ; 99
# dynamisch ; 98
# analyse ; 98
# vergleichbar ; 97
# verantwortung ; 97
# unterstützung ; 97
# unterstützen ; 97
# prozeß ; 97
# leiten ; 97
# flexibel ; 97
# übernehmen ; 96
# vollständig ; 96
# senden ; 96
# planung ; 96
# bewerbung ; 96
# mitarbeitende ; 94
# groß ; 94
# anforderung ; 93
# weiterentwicklung ; 91
# entwicklung ; 91
# qualität ; 89
# englisch ; 89
# mehrjährig ; 88
# dabei ; 87
# bitte ; 86
# arbeit ; 86
# motiviert ; 85
# herausforderung ; 85
# fachlich ; 85
# stehen ; 84
# partner ; 82
# koordination ; 82
# selbständig ; 81
# sap ; 81
# möglichkeit ; 81
# inkl ; 81
# software ; 80
# kunden ; 80
# direkt ; 80
# abwechslungsreich ; 80
# herr ; 79
# fh ; 79
# anspruchsvoll ; 79
# system ; 78
# strukturiert ; 78
# kommunikationsfähigkeit ; 78
# arbeitsweise ; 78
# sicher ; 76
# betrieb ; 76
# bestehend ; 76
# technologie ; 75
# schrift ; 75
# umgang ; 74
# teil ; 74
# projektleitung ; 74
# international ; 74
# idealerweise ; 74
# stelle ; 73
# interessant ; 73
# stellen ; 72
# 2 ; 72
# scrum ; 71
# fundiert ; 71
# frage ; 71
# arbeitsplatz ; 71
# anstellungsbedingung ; 71
# verantwortlich ; 70
# unterschiedlich ; 70
# position ; 70
# digital ; 70
# studium ; 69
# konzeption ; 69
# itprojekten ; 68
# entsprechend ; 68
# 44 ; 68
# schnittstelle ; 67
# erstellen ; 67
# beratung ; 67
# rund ; 66
# kosten ; 66
# führung ; 66
# erwarten ; 66
# erarbeiten ; 66
# denken ; 66
# wichtig ; 65
# setzen ; 65
# projektleiterin ; 65
# konzeptionell ; 65
# aktiv ; 65
# support ; 64
# freude ; 64
# erstellung ; 64
# entwickeln ; 64
# ausgeprägt ; 64
# vielseitig ; 63
# zudem ; 61
# microsoft ; 61
# kommunikativ ; 61
# implementierung ; 61
# digitalisierung ; 61
# zertifizierung ; 60
# offen ; 60
# email ; 60
# deutschkenntnisse ; 60
# zb ; 59
# erp ; 59
# 70 ; 59
# möchten ; 58
# koordinieren ; 58
# innerhalb ; 58
# engineering ; 58
# deren ; 58
# undoder ; 57
# schulung ; 57
# mitarbeiter ; 57
# mitarbeit ; 57
# information ; 57
# arbeitsumfeld ; 57
# hermes ; 56
# betriebswirtschaft ; 56
# vereinbarung ; 55
# persönlich ; 55
# ict ; 55
# durchführung ; 55
# zusammen ; 54
# stark ; 54
# interdisziplinär ; 54
# gemeinsam ; 54
# beim ; 54
# wissen ; 53
# projektteam ; 53
# einsatz ; 53
# breit ; 53
# betriebswirtschaftlich ; 53
# sofort ; 52
# kontakt ; 52
# kennen ; 52
# dokumentation ; 52
# rolle ; 51
# ipma ; 51
# führend ; 51
# funktion ; 51
# frau ; 51
# eng ; 51
# bewerben ; 51
# 100 ; 51
# konzept ; 50
# herausfordernd ; 50
# geschäftsprozeß ; 50
# erfolg ; 50
# engagiert ; 50
# betreuung ; 50
# ziel ; 49
# termin ; 49
# standort ; 49
# selbstständig ; 49
# planen ; 49
# optimierung ; 49
# besitzen ; 49
# bereits ; 49
# » ; 48
# zentral ; 48
# professionell ; 48
# maxhöggerstrasse ; 48
# erfahren ; 48
# ch8048 ; 48
# 576 ; 48
# « ; 47
# realisierung ; 47
# mehr ; 47
# manager ; 47
# lösungsorientiert ; 47
# leiter ; 47
# komplett ; 46
# itjobsyellowsharkcom ; 46
# infrastruktur ; 46
# finden ; 46
# begleiten ; 46
# auftreten ; 46
# arbeitsort ; 46
# ab ; 46
# project ; 45
# auskunft ; 45
# arbeitszeit ; 45
# 5 ; 45
# tragen ; 44
# kompetent ; 44
# erster ; 44
# anwendung ; 44
# fachbereich ; 43
# aufgaben ; 43
# stakeholdern ; 42
# sorgen ; 42
# kollegial ; 42
# hf ; 42
# handeln ; 42
# gesamt ; 42
# – ; 41
# services ; 41
# service ; 41
# netzwerk ; 41
# level ; 41
# integration ; 41
# idee ; 41
# geben ; 41
# fliessend ; 41
# branche ; 41
# bezüglich ; 41
# bedürfnis ; 41
# abteilung ; 41
# ähnlich ; 40
# via ; 40
# verfügung ; 40
# thema ; 40
# tel ; 40
# knowhow ; 40
# gehören ; 40
# französisch ; 40
# eigenverantwortlich ; 40
# vorzugsweise ; 39
# verstärkung ; 39
# steueren ; 39
# profitieren ; 39
# cloud ; 39
# abschluss ; 39
# verständnis ; 38
# senior ; 38
# itprojekte ; 38
# gestalten ; 38
# einhaltung ; 38
# bern ; 38
# verantwortungsvoll ; 37
# tätig ; 37
# transformation ; 37
# office ; 37
# hr ; 37
# teams ; 36
# sozialleistung ; 36
# nachhaltig ; 36
# möglich ; 36
# insbesondere ; 36
# geweckt ; 36
# ganz ; 36
# angebot ; 36
# 3 ; 36
# steuerung ; 35
# sicherstellung ; 35
# produkt ; 35
# muttersprache ; 35
# kommunikationsfähigkeits ; 35
# aufgabengebiet ; 35
# analysieren ; 35
# aktuell ; 35
# woche ; 34
# strategisch ; 34
# kommunikationsfähigkeitsfähigkeit ; 34
# initiative ; 34
# homeoffice ; 34
# dienstleistung ; 34
# dafür ; 34
# betreuen ; 34
# beraten ; 34
# applikation ; 34
# telefon ; 33
# spezialisieren ; 33
# risiko ; 33
# organisation ; 33
# lieferant ; 33
# kommunizieren ; 33
# itinfrastruktur ; 33
# flach ; 33
# eigen ; 33
# bzw ; 33
# aufbau ; 33
# 1 ; 33
# öffentlich ; 32
# zuständig ; 32
# zukünftig ; 32
# wwwyellowsharkcom ; 32
# weltweit ; 32
# s4hana ; 32
# requirements ; 32
# methode ; 32
# klein ; 32
# folgend ; 32
# fokus ; 32
# durchsetzungsvermögen ; 32
# budget ; 32
# 365 ; 32
# täglich ; 31
# server ; 31
# runden ; 31
# rasch ; 31
# rahmen ; 31
# onlinebewerbung ; 31
# nutzen ; 31
# mindestens ; 31
# mind ; 31
# mensch ; 31
# itprojektleiter ; 31
# evaluation ; 31
# etc ; 31
# diverser ; 31
# zukunftsorientiert ; 30
# zukunft ; 30
# wenden ; 30
# vielfältig ; 30
# uni ; 30
# umfassend ; 30
# stadt ; 30
# national ; 30
# individuell ; 30
# erarbeitung ; 30
# engagement ; 30
# dank ; 30
# ausgewiesen ; 30
# a ; 30
# überzeugend ; 29
# zeit ; 29
# tag ; 29
# strategie ; 29
# realisieren ; 29
# qualifikation ; 29
# projekten ; 29
# projekte ; 29
# m ; 29
# langjährig ; 29
# hierarchie ; 29
# finanziell ; 29
# erhalten ; 29
# einbringen ; 29
# benefits ; 29
# 2021 ; 29
# vernetzt ; 28
# stakeholder ; 28
# sicherstellen ; 28
# selbständigkeit ; 28
# klassisch ; 28
# interessiert ; 28
# gruppe ; 28
# ca ; 28
# agieren ; 28
# zielorientiert ; 27
# verantworten ; 27
# umsetzen ; 27
# to ; 27
# sprechen ; 27
# spezifikation ; 27
# schwerpunkt ; 27
# schriftlich ; 27
# relevant ; 27
# ort ; 27
# of ; 27
# nehmen ; 27
# mündlich ; 27
# messen ; 27
# itil ; 27
# innovation ; 27
# informatiker ; 27
# hinsichtlich ; 27
# flexibilität ; 27
# eth ; 27
# eigeninitiative ; 27
# definition ; 27
# bereit ; 27
# beitrag ; 27
# überzeugen ; 26
# wecken ; 26
# wachsend ; 26
# systems ; 26
# stufe ; 26
# sprache ; 26
# reibungslos ; 26
# organisatorisch ; 26
# optimal ; 26
# niveau ; 26
# neben ; 26
# logistik ; 26
# leisten ; 26
# laufend ; 26
# fördern ; 26
# erkennen ; 26
# daher ; 26
# 80100 ; 26
# zuverlässig ; 25
# wünschen ; 25
# teilprojektleitung ; 25
# praktisch ; 25
# kurz ; 25
# familiär ; 25
# eingespielt ; 25
# dossier ; 25
# berücksichtigen ; 25
# ausgezeichnet ; 25
# architektur ; 25
# arbeitgeber ; 25
# 77 ; 25
# 20 ; 25
